# %%
import sys
import os

sys.path.append(os.path.abspath("../"))

import pandas as pd
from src.cleaning import clean_coffee_pipeline


df_merged = pd.read_csv("../data/raw/merged_data_cleaned.csv")
df_final = clean_coffee_pipeline(df_merged)
df_final.to_csv("../data/processed/coffee_data_cleaned_final.csv", index=False)

print("¡Limpieza completada con éxito!")
# Out:
# ¡Limpieza completada con éxito!
